# %%
class Student :
    ''' 
    class info
    '''
    name ="Depi"
    age=5

    def std_info(self):
        print(self)
        return"hello ,depi students"

# %%
s1 = Student()
s1.name="Nada"
s1.age=21
print(s1.name)
print(s1.age)
print(s1.std_info())
# Out:
# Nada
# 21
# ...
# hello ,depi students

# %%
class student:
    def __init__(self,name,age) ->None:
        self.name =name
        self.age =age

# %%
s1 =student()
