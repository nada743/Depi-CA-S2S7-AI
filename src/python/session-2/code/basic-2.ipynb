# %%
list_one =[1,2,3,4,"Depi","learning",True,[1,2,3],"True",["ML","DL","GenAi"]]

list_one[5]="machine learning"
list_one
# Out:
# [1,
#  2,
#  3,
#  4,
#  'Depi',
#  'machine learning',
#  True,
#  [1, 2, 3],
#  'True',
#  ['ML', 'DL', 'GenAi']]

# %%
list("George")
# Out:
# ['G', 'e', 'o', 'r', 'g', 'e']

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list_1=["ML","DL"]
x=list_1.append("Deep learning")
print(list_1)
print(type(x))
# Out:
# ['ML', 'DL', 'Deep learning']
# <class 'NoneType'>

# %%
list_1.insert(1,"genai")
print(list_1)
# Out:
# ['ML', 'genai', 'DL', 'Deep learning']

# %%
list_1=["depi","learnig","python"]
list_2=["data","engineer","big data"]
list_1.extend(list_2)
list_1
# Out:
# ['depi', 'learnig', 'python', 'data', 'engineer', 'big data']

# %%
list_1=["depi","learnig","python"]
list_2=["data","engineer","big data"]
list_3=list_1+list_2
print(list_1)
print(list_3)
# Out:
# ['depi', 'learnig', 'python']
# ['depi', 'learnig', 'python', 'data', 'engineer', 'big data']

# %%
print(dir(list))
# Out:
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
list_1=["depi","learnig","python"]
list_1.remove("depi")
print(list_1)
# Out:
# ['learnig', 'python']

# %%
list_1=["depi","learnig","python","depi"]
x=list_1.pop()
print(list_1)
print(x)
print(type(x))
# Out:
# ['depi', 'learnig', 'python']
# depi
# <class 'str'>

# %%
list_1=["depi","learnig","python","depi"]
new_list=[]
pop_list=list_1.pop()
new_list.append(pop_list)
print(list_1)
print(new_list)
# Out:
# ['depi', 'learnig', 'python']
# ['depi']

# %%
list_1=["depi","learnig","python","depi"]
del list_1[:]
list_1
# Out:
# []

# %%
list_2=["depi","learnig","python","depi"]
list_2.clear()
list_2
# Out:
# []

# %%
print("g")

# %%
x=input("input input") 
input_list =["ml","dl","data"]
input_list.remove(x)
input_list

# %%
list_1 =[4,2,3,1]
list_1.sort()
list_1
# Out:
# [1, 2, 3, 4]

# %%
list_4 =[4,2,3,1]
x=sorted(list_4)
print(x)
print(list_4)
# Out:
# [1, 2, 3, 4]
# [4, 2, 3, 1]

# %%
list_4 =[4,2,3,1]
list_4.reverse()
list_4
# Out:
# [1, 3, 2, 4]

# %%
tup1=("depi","learning","python","depi")
type(tup1)
# Out:
# tuple

# %%
name=["name","age"]
new_tup=tuple(name)
print(new_tup)
print(type(new_tup))
# Out:
# ('name', 'age')
# <class 'tuple'>

# %%
set1={"depi","learning","depi"}
print(type(set1))
# set[1] = "deep"
set1
# Out:
# <class 'set'>
# {'depi', 'learning'}

# %%
lst1=["fcldl","dsc","fklck","depi","depi"]
set(lst1)
# Out:
# {'depi', 'dsc', 'fcldl', 'fklck'}

# %%
my_set ={3,4,4,1,6,7,8,7}
my_set.add(6)
my_set
# Out:
# {1, 3, 4, 6, 7, 8}

# %%
data1 ={101,102,103,104}
data2={103,104,105,106}
print(data1.intersection(data2))
# Out:
# {104, 103}

# %%
# dict={"k1":7,"k2":8,"k3":21}
# dict["k1"]="Depi"
# dict
# Out:
# {'k1': 'Depi', 'k2': 8, 'k3': 21}

# %%
list1 =[('a',10),('b',20),('c',30)]
new_dict = dict(list1)
print(new_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 list1 =[('a',10),('b',20),('c',30)]
# ----> 2 new_dict = dict(list1)
#       3 print(new_dict)
#
# TypeError: 'dict' object is not callable

# %%
chatbot ={"hello":"helli how",
          "python":"python is",
          "ai":"ai is"
}
print(chatbot.keys())

question = input("question ").lower()
print(chatbot.get(question,"not found"))
# Out:
# dict_keys(['hello', 'python', 'ai'])
# not found

# %%
num1=float(input("enter num1"))
num2=float(input("enter num2"))
print("sum",(num1)+(num2))
print("sub",(num1-num2))
print("div",(num1)/(num2))
print("mul",(num1)*(num2))
# Out:
# sum 15.0
# sub 5.0
# div 2.0
# mul 50.0

# %%
a=200
b=30
if a>b:
    print("b is greater")
elif b==30:
    print("b")
if b>a:
    print("b is greater")
if b>a:
    print("b is greater")
# Out:
# b is greater
