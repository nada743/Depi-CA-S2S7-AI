# %%
print("hello")
# Out:
# Running cells with 'Python 3.12.10' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/ca-ai/.venv-Depi/Scripts/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
print("hello")
# Out:
# hello

# %%
name ="nada"
age= 21
print("my name is {1} and age is {0}" .format(name, age))
# Out:
# my name is 21 and age is nada

# %%
print(f"my name is {name} and my age is {age
}")
# Out:
# my name is nada and my age is 21

# %%
name="nada"
age=21
cource_name="python"
output =f"my name is {name} and age is {age} and take {cource_name}"
print(output)
# Out:
# my name is nada and age is 21 and take python

# %%
x=[1,2,3,4,"5","hi"]
x[0]=100
print(x[0])
print (type(x))
# Out:
# 100
# <class 'list'>

# %%
tup1=(2,3)
print(type(tup1))
# Out:
# <class 'tuple'>

# %%
s={1,2,3}
print(type(s))
# Out:
# <class 'set'>

# %%
name ="depi for everyone"
name[5 :8 :1]
# Out:
# 'for'

# %%
name = "depi for machine learning"

# %%
capital=name.upper()
capital
# Out:
# 'DEPI FOR MACHINE LEARNING'

# %%
capital.lower()
# Out:
# 'depi for machine learning'

# %%
name ="depi for machine learning and depi for genai"
name.replace("machine","deep learning")
# Out:
# 'depi for deep learning learning and depi for genai'

# %%
name.capitalize()
# Out:
# 'Depi for machine learning and depi for genai'

# %%
name.title()
# Out:
# 'Depi For Machine Learning And Depi For Genai'

# %%
name.count("depi")
# Out:
# 2

# %%
x=name.split()
x
# Out:
# ['depi', 'for', 'machine', 'learning', 'and', 'depi', 'for', 'genai']

# %%
new_x= ' '.join(x)
new_x
# Out:
# 'depi for machine learning and depi for genai'

# %%
print("hello\" depi\" and nti ")
# Out:
# hello" depi" and nti

# %%
x="Amit_ml@gmail.edu"
if x.count("@") !=1:
    print("Invalid email")
t=x.index("@")
if "." not in x[t:]:
    print("Invalid email")
extract_x=x[0:t]
n=x.rfind(".")
extract_dom=x[t:n]
print(extract_dom)
if x.endswith(".com"):
    print("Commercial Domain")
elif x.endswith(".edu"):
    print("Educational Domain")
else :
    print("Other Domain")
# Out:
# @gmail
# Educational Domain

# %%
y="###!!@mocleW EPGTQ!!!6789"
ex=y[6:18:1]
rev=ex[:6][::-1]
rep=ex.replace("E","")
new=rev+rep[6:]
print(new)
# Out:
# Welcom PGTQ

# %%
mes="&&&**$gnirtS PLIO!!@1234 "
ext=mes[6:17]
reve=ext[:6][::-1]
rep1=ext.replace("I","E")
rep2=rep1.replace("O","U")
fin=reve+rep2[6:11]
print(fin)
# Out:
# String PLEU

# %%
mess="##$$$@!yalpstcejorp EPUVT****9887"
part=mess[7:25]
rever=part[:12][::-1]
repl1=part.replace("E","A")
repl2=repl1.replace("U","O")
mess2=rever+repl2[12:25]
print(mess2)
# Out:
# projectsplay APOVT

# %%
print("my name is nada" ,21)
