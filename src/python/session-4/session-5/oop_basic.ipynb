# %%
# Predefined responses
import random
responses = {
    "hello": ["Hello!", "Hi there!", "Greetings!"],
    "how are you": ["I'm doing well, thank you!", "I'm fine, how about you?"],
    "goodbye": ["Goodbye!", "See you later!", "Farewell!"],
    "default": ["I'm sorry, I didn't understand.", "Could you please rephrase that?"]
}

def get_response(user_input):
    for key in responses:
        if key in user_input:
            return random.choice(responses[key])
    return random.choice(responses["default"])

# %%
import random
import json

with open("C:/Users/AMIT/Desktop/Bns-s2s2-ai/BNS_AIS2_S2_Ml/src/python/session-5/data.json","r") as file:
    responses = json.load(file)

# %%
responses
# Out:
# {'hello': ['Hello!', 'Hi there!', 'Greetings!'],
#  'how are you': ["I'm doing well, thank you!", "I'm fine, how about you?"],
#  'goodbye': ['Goodbye!', 'See you later!', 'Farewell!'],
#  'default': ["I'm sorry, I didn't understand.",
#   'Could you please rephrase that?']}

# %%
def add(x,y):
    return x+y


def add(x,y):
    return x+y


def add(x,y):
    return x+y

def add(x,y):
    return x+y

# %%
class Student:
    
    name = "George"
    age = 39
    
    def std_info(self):
        print(name, age )

# %%
s1 = Student()
s1.
print(s1)
s1.std_info()

# %%
class Student:
    
    def __init__(self, name, age):
        self.name = name
        self.age = age
        self.grade = 10
        
    def std_info(self):
        return f"My name is {self.name}, my age is {self.age}"

# %%
s1 =Student("depi", 5)
s1.std_info()
# Out:
# 'My name is depi, my age is 5'

# %%
'''  
this class response for ...............

'''



class Calc:
    """
    
    
    
    """
    def __init__(self, x:int, y:int) -> None:
        """
        
        """
        self.x = x
        self.y = y
        
    def add(self):
        ''' 
        
        
        '''
        return self.x + self.y
     
    def sub(self):
        return self.x - self.y

# %%
x  = int(input("enter first number"))
y  = int(input("enter second number"))

c1 = Calc(x,y)
c1.sub()
# Out:
# -10

# %%
import math

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    
    @abstractmethod
    def move(self):
        pass
        
    
class Bird(Animal):
    pass

class Cat(Animal):
    
    def move(self):
        print("move from cat")
class Dothis(Cat):
    pass

# %%
d1 = Dothis()
d1.move()
# Out:
# move from cat

# %%
list
lst = [1,2,3]
lst.clear()

# %%
class Rectangle:
    __length = 5
    _width = 10
    
    def area(self):
        return self.__length * self._width
    
r = Rectangle()
print(r._Rectangle__length)
print(r._width)
print(r.area())
# Out:
# 5
# 10
# 50

# %%
class parent:
    def __init__(self) -> None:
        self.__value = 10


class child(parent):
    def __init__(self) -> None:
        super().__init__()
        self.__value = 20

# %%
c = child()
print(c.__dict__)
# Out:
# {'_parent__value': 10, '_child__value': 20}

# %%
class Dog:
    def speak(self):
        return "woof"
    
class Cat:
    def speak(self):
        print("meow")

def make_sound(animal):
    print(animal.speak())
# d  = Dog()
# c = Cat()
make_sound(Cat())
# print(make_sound(Cat()))
# Out:
# meow
# None

# %%
*add

# %%
c1 = Calc()
c1.add(10)
# Out:
# 10
